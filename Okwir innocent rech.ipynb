# %%
import geopandas as gpd

# %%
gdf.crs
# Out:
# <Projected CRS: EPSG:21096>
# Name: Arc 1960 / UTM zone 36N
# Axis Info [cartesian]:
# - E[east]: Easting (metre)
# - N[north]: Northing (metre)
# Area of Use:
# - name: Africa - Kenya and Uganda - north of equator and 30°E to 36°E
# - bounds: (29.99, 0.0, 36.0, 4.63)
# Coordinate Operation:
# - name: UTM zone 36N
# - method: Transverse Mercator
# Datum: Arc 1960
# - Ellipsoid: Clarke 1880 (RGS)
# - Prime Meridian: Greenwich

# %%
gdf.plot()
# Out:
# <AxesSubplot:>

# %%
import geopandas as gpd

# %%
gdf=gpd.read_file("C:/Users/OKWIR INNOCENT/Desktop/shape files/Neighbourhood.shp")

# %%
gdf
# Out:
#    Id             Name                                           geometry
# 0   0      Neighbour 1  POLYGON ((453544.891 39788.584, 453549.759 398...
# 1   0      Neighbour 2  POLYGON ((453533.673 39754.928, 453542.563 397...
# 2   0  Lower Neighbour  POLYGON ((453545.949 39803.824, 453545.526 398...
# 3   0      Neighbour 3  MULTIPOLYGON (((453506.791 39764.877, 453506.5...

# %%
gdf.crs
# Out:
# <Projected CRS: EPSG:21096>
# Name: Arc 1960 / UTM zone 36N
# Axis Info [cartesian]:
# - E[east]: Easting (metre)
# - N[north]: Northing (metre)
# Area of Use:
# - name: Africa - Kenya and Uganda - north of equator and 30°E to 36°E
# - bounds: (29.99, 0.0, 36.0, 4.63)
# Coordinate Operation:
# - name: UTM zone 36N
# - method: Transverse Mercator
# Datum: Arc 1960
# - Ellipsoid: Clarke 1880 (RGS)
# - Prime Meridian: Greenwich

# %%
gdf.plot()
# Out:
# <AxesSubplot:>
